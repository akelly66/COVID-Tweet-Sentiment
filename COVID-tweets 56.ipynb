# %% [markdown]
# # Sentiment Analysis of COVID-19 Tweets: When did the Public Panic Set In?

# %%
import pandas as pd
import json
import tweepy
import requests

import searchtweets
from searchtweets import load_credentials

# %%
credentials = load_credentials(filename="/Users/Allie/Documents/DS-Projects/COVID-Tweet-Sentiment/.secret/twitter_keys.yaml",
                 yaml_key="search_tweets_api",
                 env_overwrite=False)
# Out:
# Grabbing bearer token from OAUTH

# %%
endpoint = 'https://api.twitter.com/1.1/tweets/search/fullarchive/production.json'

headers = {"Authorization":"Bearer AAAAAAAAAAAAAAAAAAAAAJT5DwEAAAAAPsNhYZ%2FC62bgQd8XU9SG4vMmb8U%3DMc4rj6InQh0MUdfAc22Xc33qYqPeCwTE22DO3hleWSsNOBN1nF", "Content-Type": "application/json"}  

data = '{"query":"(coronavirus OR COVID-19)", "fromDate": "202001300000", "toDate": "202001312359"}, {"place":{"profile_country":"United States of America"}}'

response = requests.post(endpoint,data=data,headers=headers).json()

# %%
response['next']
# Out:
# 'eyJtYXhJZCI6MTIyMzM5NTI1MzQ3NjExMDM0NH0='

# %%
print(json.dumps(response, indent = 2)).keys()
# Out:
# {
#   "results": [
#     {
#       "created_at": "Fri Jan 31 23:58:59 +0000 2020",
#       "id": 1223395284119695360,
#       "id_str": "1223395284119695360",
#       "text": "No les miento....\nEse Coronavirus me tiene asustada \ud83d\ude22\ud83d\ude22\ud83d\ude25",
#       "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#       "truncated": false,
#       "in_reply_to_status_id": null,
#       "in_reply_to_status_id_str": null,
#       "in_reply_to_user_id": null,
#       "in_reply_to_user_id_str": null,
#       "in_reply_to_screen_name": null,
#       "user": {
#         "id": 1187527343562264576,
#         "id_str": "1187527343562264576",
#         "name": "\u2022| Wininini\ud83c\udf12\ud83d\udda4|\u2022",
#         "screen_name": "winiffer_perez",
#         "location": "Caracas Venezuela",
#         "url": null,
# ...

# %%
df = pd.DataFrame.from_dict(response['results'])

# %%
len(df)
# Out:
# 100

# %%
data2 = '{"query":"(coronavirus OR COVID-19)", "fromDate": "202001300000", "toDate": "202001312359", "next":"eyJtYXhJZCI6MTIyMzM5NTI1MzQ3NjExMDM0NH0="}, {"place":{"profile_country":"United States of America"}}'

response2 = requests.post(endpoint,data=data2,headers=headers).json()

# %%
response2['results']
# Out:
# [{'created_at': 'Fri Jan 31 23:58:52 +0000 2020',
#   'id': 1223395253362642945,
#   'id_str': '1223395253362642945',
#   'text': 'RT @WhiteHouse: LIVE: Press Briefing with Members of Coronavirus Task Force https://t.co/uTydIkjCtH',
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1905556350,
#    'id_str': '1905556350',
#    'name': 'PC YOUNG',
#    'screen_name': 'Conservamator',
#    'location': 'California, USA',
#    'url': None,
#    'description': 'Rtd Process Eng Molecular Biologist BioChemist Christian, #MAGA #KAGA2020 #CCOT The_Entropist https://minds.com http://conservamator2014.wordpress.com',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
# ...

# %%
def get_next_code(response):
    
    next = response['next']

# %%
response['next']
# Out:
# 'eyJtYXhJZCI6MTIyMzM5NTI1MzQ3NjExMDM0NH0='

# %%
response2['next']
# Out:
# 'eyJtYXhJZCI6MTIyMzM5NTIyNzcxMDUwMDg2NX0='

# %%
data3 = '{"query":"(coronavirus OR COVID-19)", "fromDate": "202001300000", "toDate": "202001312359"}, {"place":{"profile_country":"United States of America"},{"next":"eyJtYXhJZCI6MTIyMzM5NTI1MzQ3NjExMDM0NH0="}}'

response3 = requests.post(endpoint,data=data3,headers=headers).json()

# %%
df2 = pd.DataFrame.from_dict(response2['results'])

# %%
df2.head()
# Out:
#                        created_at                   id               id_str  \
# 0  Fri Jan 31 23:58:59 +0000 2020  1223395284119695360  1223395284119695360
# 1  Fri Jan 31 23:58:59 +0000 2020  1223395283796746242  1223395283796746242
# 2  Fri Jan 31 23:58:59 +0000 2020  1223395283477897216  1223395283477897216
# 3  Fri Jan 31 23:58:59 +0000 2020  1223395283121442816  1223395283121442816
# 4  Fri Jan 31 23:58:59 +0000 2020  1223395282538369024  1223395282538369024
#
#                                                 text  \
# 0  No les miento....\nEse Coronavirus me tiene as...
# 1  RT @CNN: There have been more than 9,800 cases...
# 2  RT @CanSaludable: Preguntas y respuestas #coro...
# 3  RT @sanidadgob: El Centro Nacional de Microbio...
# 4  RT @JaneLytv: 43. Zero Hedge, a pro-Trump webs...
#
#                                               source  truncated  \
# 0  <a href="https://mobile.twitter.com" rel="nofo...      False
# ...

# %%
df3 = pd.DataFrame.from_dict(response3['results'])

# %%
df3.head()
# Out:
#                        created_at                   id               id_str  \
# 0  Fri Jan 31 23:58:59 +0000 2020  1223395284119695360  1223395284119695360
# 1  Fri Jan 31 23:58:59 +0000 2020  1223395283796746242  1223395283796746242
# 2  Fri Jan 31 23:58:59 +0000 2020  1223395283477897216  1223395283477897216
# 3  Fri Jan 31 23:58:59 +0000 2020  1223395283121442816  1223395283121442816
# 4  Fri Jan 31 23:58:59 +0000 2020  1223395282538369024  1223395282538369024
#
#                                                 text  \
# 0  No les miento....\nEse Coronavirus me tiene as...
# 1  RT @CNN: There have been more than 9,800 cases...
# 2  RT @CanSaludable: Preguntas y respuestas #coro...
# 3  RT @sanidadgob: El Centro Nacional de Microbio...
# 4  RT @JaneLytv: 43. Zero Hedge, a pro-Trump webs...
#
#                                               source  truncated  \
# 0  <a href="https://mobile.twitter.com" rel="nofo...      False
# ...

# %%
endpoint = 'https://api.twitter.com/1.1/tweets/search/fullarchive/production.json'

headers = {"Authorization":"Bearer AAAAAAAAAAAAAAAAAAAAAJT5DwEAAAAAPsNhYZ%2FC62bgQd8XU9SG4vMmb8U%3DMc4rj6InQh0MUdfAc22Xc33qYqPeCwTE22DO3hleWSsNOBN1nF", "Content-Type": "application/json"}  

def paginate_covid_tweets(endpoint, headers):
    next_tokens = []

    data = f'{"query":"(coronavirus OR COVID-19)", "fromDate": "202001300000", "toDate": "202001312359", "next":{next_tokens[-1]}}, {"place":{"profile_country":"United States of America"}}'

    response = requests.post(endpoint,data=data,headers=headers).json()

# %%
df=pd.concat([df,df2,df3],axis=0 )

# %%
response3['next']
# Out:
# 'eyJtYXhJZCI6MTIyMzM5NTI1MzM2MjY0Mjk0NX0='

# %%
data4 = '{"query":"(coronavirus OR COVID-19)", "fromDate": "202001300000", "toDate": "202001312359","next":"eyJtYXhJZCI6MTIyMzM5NTI1MzM2MjY0Mjk0NX0="}, {"place":{"profile_country":"United States of America"}}'

response4 = requests.post(endpoint,data=data4,headers=headers).json()
df4 = pd.DataFrame.from_dict(response4['results'])
df=pd.concat([df,df4],axis=0 )
response4['next']
# Out:
# 'eyJtYXhJZCI6MTIyMzM5NTIyNzY4NTMyNjg1NH0='

# %%
data5 = '{"query":"(coronavirus OR COVID-19)", "fromDate": "202001300000", "toDate": "202001312359","next":"eyJtYXhJZCI6MTIyMzM5NTIyNzY4NTMyNjg1NH0="}, {"place":{"profile_country":"United States of America"}}'

response5 = requests.post(endpoint,data=data5,headers=headers).json()
df5 = pd.DataFrame.from_dict(response5['results'])
df=pd.concat([df,df5],axis=0 )
print(len(df))
response5['next']
# Out:
# 500
# 'eyJtYXhJZCI6MTIyMzM5NTIyNzY4NTMyNjg1NH0='

# %%
data6 = '{"query":"(coronavirus OR COVID-19)", "fromDate": "202001300000", "toDate": "202001312359","next":"eyJtYXhJZCI6MTIyMzM5NTIwMzI0OTI5NTM2MX0="}, {"place":{"profile_country":"United States of America"}}'

response6 = requests.post(endpoint,data=data6,headers=headers).json()
df6 = pd.DataFrame.from_dict(response6['results'])
df=pd.concat([df,df6],axis=0 )
print(len(df))
response6['next']
# Out:
# 600
# 'eyJtYXhJZCI6MTIyMzM5NTE3NTU4NzgzMTgwOH0='

# %%
data7 = '{"query":"(coronavirus OR COVID-19)", "fromDate": "202001300000", "toDate": "202001312359","next":"eyJtYXhJZCI6MTIyMzM5NTE3NTU4NzgzMTgwOH0="}, {"place":{"profile_country":"United States of America"}}'

response7 = requests.post(endpoint,data=data7,headers=headers).json()
df7 = pd.DataFrame.from_dict(response7['results'])
df=pd.concat([df,df7],axis=0 )
print(len(df))
response7['next']
# Out:
# 700
# 'eyJtYXhJZCI6MTIyMzM5NTE1MTg2NDY4NDU0NH0='

# %%
data8 = '{"query":"(coronavirus OR COVID-19)", "fromDate": "202001300000", "toDate": "202001312359","next":"eyJtYXhJZCI6MTIyMzM5NTE1MTg2NDY4NDU0NH0="}, {"place":{"profile_country":"United States of America"}}'

response8 = requests.post(endpoint,data=data8,headers=headers).json()
df8 = pd.DataFrame.from_dict(response8['results'])
df=pd.concat([df,df8],axis=0 )
print(len(df))
response8['next']
# Out:
# 800
# 'eyJtYXhJZCI6MTIyMzM5NTEyNDg0NTE0MjAxN30='

# %%
data9 = '{"query":"(coronavirus OR COVID-19)", "fromDate": "202001300000", "toDate": "202001312359","next":"eyJtYXhJZCI6MTIyMzM5NTEyNDg0NTE0MjAxN30="}, {"place":{"profile_country":"United States of America"}}'

response9 = requests.post(endpoint,data=data9,headers=headers).json()
df9 = pd.DataFrame.from_dict(response9['results'])
df=pd.concat([df,df9],axis=0 )
print(len(df))
response9['next']
# Out:
# 900
# 'eyJtYXhJZCI6MTIyMzM5NTEwMTg4MTM3MjY3M30='

# %%
from string import Template

t=Template('{"query":"(coronavirus OR COVID-19)", "fromDate": "202001300000", "toDate": "202001312359","next":"${key}"}, {"place":{"profile_country":"United States of America"}}')
data10 = t.substitute(key=response9['next'])

# %%
data10 = '{"query":"(coronavirus OR COVID-19)", "fromDate": "202001300000", "toDate": "202001312359","next":"eyJtYXhJZCI6MTIyMzM5NTEyNDg0NTE0MjAxN30="}, {"place":{"profile_country":"United States of America"}}'

response10 = requests.post(endpoint,data=data10,headers=headers).json()
df10 = pd.DataFrame.from_dict(response10['results'])
df=pd.concat([df,df10],axis=0 )
print(len(df))
response10['next']
# Out:
# 1000
# 'eyJtYXhJZCI6MTIyMzM5NTEwMTg4MTM3MjY3M30='

# %%
def paginate_covid_tweets(endpoint, headers, previous_response_token=None):
    
    global next_token
    
    if previous_response_token:
        t=Template('{"query":"(coronavirus OR COVID-19)", "fromDate": "202001300000", "toDate": "202001312359","next":"${next_token}"}, {"place":{"profile_country":"United States of America"}}')
        data = t.substitute(next_token=previous_response_token)
        
        response = requests.post(endpoint,data=data,headers=headers).json()
        next_token = response['next']
        
        return response, next_token
    
    elif previous_response_token == False: 
        
    
        data = '{"query":"(coronavirus OR COVID-19)", "fromDate": "202001300000", "toDate": "202001312359","next":"${next_token}"}, {"place":{"profile_country":"United States of America"}}'
    
    
        response = requests.post(endpoint,data=data,headers=headers).json()
        next_token = response['next']
        
        return response, next_token
    
    else:
        return "Response Error"

# %%
paginate_covid_tweets(endpoint, headers, response10['next'] )
# Out:
# ({'results': [{'created_at': 'Fri Jan 31 23:58:16 +0000 2020',
#     'id': 1223395101482868736,
#     'id_str': '1223395101482868736',
#     'text': 'El alemán aislado en la Gomera por el coronavirus https://t.co/c4wT6qJ489',
#     'display_text_range': [0, 49],
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'truncated': False,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 344815159,
#      'id_str': '344815159',
#      'name': '✨Mr.Faith♌',
#      'screen_name': 'MrFaith91',
#      'location': 'Springfield ',
#      'url': None,
#      'description': "Desde Wisteria Lane 🍎 hasta Storybrooke 🌜descendiente de los Targaryen 🐉 y las Halliwell 🌌 Eat my shit 💩 and express yourself 🌈 but don't fuck it up 💅",
#      'translator_type': 'none',
# ...
