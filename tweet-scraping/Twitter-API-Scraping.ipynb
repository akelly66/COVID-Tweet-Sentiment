# %% [markdown]
# # Sentiment Analysis of COVID-19 Tweets: When did the Public Panic Set In? Part 1: Scraping Tweets

# %% [markdown]
#     Notebook by Allison Kelly - allisonkelly42@gmail.com

# %% [markdown]
# # Introduction
#
# <i>This notebook is part one of my NLP project aiming to scrape and analyze tweets regarding the coronavirus pandemic. <br>View part two <a href="https://github.com/akelly66/COVID-Tweet-Sentiment/blob/master/text-processing/COVID-tweet-NLP.ipynb">here</a>.</i>
#
# Love it or hate it, social media has gone from angsty teenagers posting poetry on LiVEJOURNAL to the leader of the free world <a href="https://twitter.com/realDonaldTrump/status/1213919480574812160?ref_src=twsrc%5Etfw%7Ctwcamp%5Etweetembed%7Ctwterm%5E1213919480574812160&ref_url=https%3A%2F%2Fmashable.com%2Farticle%2Ftrump-tweets-congress-war-powers-act%2F">waging war on Iran</a> in 265 words (or less) in a matter of years. Social media provides analysts with <i><a href="https://seedscientific.com/how-much-data-is-created-every-day/">zettabytes</a></i> of data every day. That's 1,000 bytes to the seventh power. Specifically, Twitter users generate 500 million tweets per day, of which the content of those Tweets contains invaluable public opinion data.
#
# As the world has been turned on its head during the COVID-19 global pandemic, an interesting question arises. How seriously is the public taking the pandemic? Millions have lost their jobs, deaths from the disease are in the hundreds each day, and the US meat supply chain is on the brink of failure, but life-saving shelter-in-place orders are being defied as protesters rally all over the country in favor of opening the ecomony.
#
# The question I seek to answer in this project is whether the public opinion of how serious the pandemic was changed in the United States once the World Health Organization declared a global pandemic. This is not meant to be academically rigorous. As I only have access to a Premium API Sandbox dev environment, I had to scale down my query to only include tweets containing two keywords, "COVID-19" and "coronavirus," and a limit of 5,000 tweets scraped per month. I chose the 24 hours before and after the declaration on January 31, 2020, though this will give a limited scope as stay-at-home orders did not begin until mid-March.
#
# The following code will demonstrate how I scraped tweets using the <a href="https://github.com/twitterdev/search-tweets-python">searchtweets</a> and <a href="https://pypi.org/project/requests/2.7.0/">requests</a> packages once connected to the Twitter API.

# %% [markdown]
# # Imports

# %%
import pandas as pd
import json
import requests

import searchtweets
from searchtweets import load_credentials
from string import Template

# To pause function to respect request limits
import time

# Saving and importing previous next tokens
import pickle

# %% [markdown]
# # OAUTH 2.0 Bearer Token
#
# After following the Twitter Developer <a href="https://developer.twitter.com/en/docs/basics/getting-started">Getting Started</a> guide, I created a developer app, received API keys, and generated a bearer token from OAuth 2.0. My API keys are housed in a secret YAML document, separate from the repository used to house this notebook.

# %%
credentials = load_credentials(filename="/Users/Allie/Documents/DS-Projects/API keys/twitter_keys.yaml",
                 yaml_key="search_tweets_api",
                 env_overwrite=False)
# Out:
# Grabbing bearer token from OAUTH

# %%
bearer_token = credentials['bearer_token']

# %% [markdown]
# # Initial Request
#
# In order to test my search parameters, I'm making an initial request to the Twitter API Full Archive. The parameters I'm using for this project are the following:
#
#    - <b>Keywords: </b> "coronavirus OR Wuhan virus OR 2019-nCoV OR China flu"<br>
#    <br> This keyword list will not be exhaustive of all tweets relating to COVID-19 during this time period but I believe will be enough to get an impression of the public response to the WHO's declaration of a pandemic. <br><br>
#    - <b>Date Range: </b> 28 Jan 2020 -  03 Feb 2020<br><br>
#    The pandemic was declared on January 31, 2020. The few days that bookend this date can offer a more concrete examination of public perception pre- and post-declaration
#    <br><br>
#    - <b>Location:</b> United States of America<br><br>
#    By using the profile_country parameter, the selected tweets will be tweets or retweets of profiles that indicate the US is their geographical location, though they may have tweeted from abroad or retweeted non-Americans. I don't believe this should alter the intended sentiment.

# %%
# Full archive endpoint
endpoint = 'https://api.twitter.com/1.1/tweets/search/fullarchive/production.json'

headers = {"Authorization":"Bearer {}".format(bearer_token), 
           "Content-Type": "application/json"}  

data = '{"query":"(coronavirus OR Wuhan virus OR 2019-nCoV OR China flu) lang:en", "fromDate": "202001280000", "toDate":"202002030000"}, {"place":{"profile_country":"United States of America"}}'

# POST request instead of GET to avoid URL length restrictions of 2048 characters
response = requests.post(endpoint,data=data,headers=headers).json()

# %% [markdown]
# Next, we'll use JSON to decode the response into a "pretty-printed" string to explore the results of the request to see if everything checks out.

# %%
# Indenting to pretty-print
print(json.dumps(response, indent = 2))
# Out:
# {
#   "results": [
#     {
#       "created_at": "Fri Jan 31 23:58:59 +0000 2020",
#       "id": 1223395283796746242,
#       "id_str": "1223395283796746242",
#       "text": "RT @CNN: There have been more than 9,800 cases of Wuhan coronavirus globally as of Friday afternoon https://t.co/xOkzBGD2lB https://t.co/9c\u2026",
#       "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#       "truncated": false,
#       "in_reply_to_status_id": null,
#       "in_reply_to_status_id_str": null,
#       "in_reply_to_user_id": null,
#       "in_reply_to_user_id_str": null,
#       "in_reply_to_screen_name": null,
#       "user": {
#         "id": 292918761,
#         "id_str": "292918761",
#         "name": "Kathleen",
#         "screen_name": "Doralgal",
#         "location": "Massachusetts, USA",
#         "url": null,
#         "description": "I fear for the future of our democracy. Vote, never give up. Wife, mother, grandmother, ER RN, humanist. #TheyKnew #TeamJustice #BidenHarris2020",
#         "translator_type": "none",
#         "protected": false,
#         "verified": false,
#         "followers_count": 3016,
#         "friends_count": 3040,
#         "listed_count": 1,
#         "favourites_count": 73736,
#         "statuses_count": 75589,
#         "created_at": "Wed May 04 13:16:00 +0000 2011",
#         "utc_offset": null,
#         "time_zone": null,
#         "geo_enabled": false,
#         "lang": null,
#         "contributors_enabled": false,
#         "is_translator": false,
#         "profile_background_color": "0099B9",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme4/bg.gif",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme4/bg.gif",
#         "profile_background_tile": false,
#         "profile_link_color": "0099B9",
#         "profile_sidebar_border_color": "5ED4DC",
#         "profile_sidebar_fill_color": "95E8EC",
#         "profile_text_color": "3C3940",
#         "profile_use_background_image": true,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1297334601598328832/ObdK5pTG_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1297334601598328832/ObdK5pTG_normal.jpg",
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/292918761/1597270455",
#         "default_profile": false,
#         "default_profile_image": false,
#         "following": null,
#         "follow_request_sent": null,
#         "notifications": null
#       },
#       "geo": null,
#       "coordinates": null,
#       "place": null,
#       "contributors": null,
#       "retweeted_status": {
#         "created_at": "Fri Jan 31 23:30:08 +0000 2020",
#         "id": 1223388022382743552,
#         "id_str": "1223388022382743552",
#         "text": "There have been more than 9,800 cases of Wuhan coronavirus globally as of Friday afternoon https://t.co/xOkzBGD2lB https://t.co/9ccoM502bf",
#         "display_text_range": [
#           0,
#           114
#         ],
#         "source": "<a href=\"http://www.socialflow.com\" rel=\"nofollow\">SocialFlow</a>",
#         "truncated": false,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#           "id": 759251,
#           "id_str": "759251",
#           "name": "CNN",
#           "screen_name": "CNN",
#           "location": null,
#           "url": "http://www.cnn.com",
#           "description": "It\u2019s our job to #GoThere & tell the most difficult stories. Join us! For more breaking news updates follow @CNNBRK & download our app http://cnn.com/apps",
#           "translator_type": "regular",
#           "protected": false,
#           "verified": true,
#           "followers_count": 49787965,
#           "friends_count": 1106,
#           "listed_count": 141168,
#           "favourites_count": 1423,
#           "statuses_count": 317199,
#           "created_at": "Fri Feb 09 00:35:02 +0000 2007",
#           "utc_offset": null,
#           "time_zone": null,
#           "geo_enabled": true,
#           "lang": null,
#           "contributors_enabled": false,
#           "is_translator": false,
#           "profile_background_color": "323232",
#           "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#           "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#           "profile_background_tile": false,
#           "profile_link_color": "004287",
#           "profile_sidebar_border_color": "000000",
#           "profile_sidebar_fill_color": "EEEEEE",
#           "profile_text_color": "000000",
#           "profile_use_background_image": false,
#           "profile_image_url": "http://pbs.twimg.com/profile_images/1278259160644227073/MfCyF7CG_normal.jpg",
#           "profile_image_url_https": "https://pbs.twimg.com/profile_images/1278259160644227073/MfCyF7CG_normal.jpg",
#           "profile_banner_url": "https://pbs.twimg.com/profile_banners/759251/1564637377",
#           "default_profile": false,
#           "default_profile_image": false,
#           "following": null,
#           "follow_request_sent": null,
#           "notifications": null
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "quote_count": 25,
#         "reply_count": 53,
#         "retweet_count": 264,
#         "favorite_count": 316,
#         "entities": {
#           "hashtags": [],
#           "urls": [
#             {
#               "url": "https://t.co/xOkzBGD2lB",
#               "expanded_url": "https://cnn.it/2S8rapt",
#               "display_url": "cnn.it/2S8rapt",
#               "indices": [
#                 91,
#                 114
#               ]
#             }
#           ],
#           "user_mentions": [],
#           "symbols": [],
#           "media": [
#             {
#               "id": 1223388020101079040,
#               "id_str": "1223388020101079040",
#               "indices": [
#                 115,
#                 138
#               ],
#               "media_url": "http://pbs.twimg.com/media/EPpY7CiX4AAfjii.jpg",
#               "media_url_https": "https://pbs.twimg.com/media/EPpY7CiX4AAfjii.jpg",
#               "url": "https://t.co/9ccoM502bf",
#               "display_url": "pic.twitter.com/9ccoM502bf",
#               "expanded_url": "https://twitter.com/CNN/status/1223388022382743552/photo/1",
#               "type": "photo",
#               "sizes": {
#                 "medium": {
#                   "w": 1192,
#                   "h": 1200,
#                   "resize": "fit"
#                 },
#                 "thumb": {
#                   "w": 150,
#                   "h": 150,
#                   "resize": "crop"
#                 },
#                 "small": {
#                   "w": 676,
#                   "h": 680,
#                   "resize": "fit"
#                 },
#                 "large": {
#                   "w": 1560,
#                   "h": 1570,
#                   "resize": "fit"
#                 }
#               }
#             }
#           ]
#         },
#         "extended_entities": {
#           "media": [
#             {
#               "id": 1223388020101079040,
#               "id_str": "1223388020101079040",
#               "indices": [
#                 115,
#                 138
#               ],
#               "media_url": "http://pbs.twimg.com/media/EPpY7CiX4AAfjii.jpg",
#               "media_url_https": "https://pbs.twimg.com/media/EPpY7CiX4AAfjii.jpg",
#               "url": "https://t.co/9ccoM502bf",
#               "display_url": "pic.twitter.com/9ccoM502bf",
#               "expanded_url": "https://twitter.com/CNN/status/1223388022382743552/photo/1",
#               "type": "photo",
#               "sizes": {
#                 "medium": {
#                   "w": 1192,
#                   "h": 1200,
#                   "resize": "fit"
#                 },
#                 "thumb": {
#                   "w": 150,
#                   "h": 150,
#                   "resize": "crop"
#                 },
#                 "small": {
#                   "w": 676,
#                   "h": 680,
#                   "resize": "fit"
#                 },
#                 "large": {
#                   "w": 1560,
#                   "h": 1570,
#                   "resize": "fit"
#                 }
#               }
#             }
#           ]
#         },
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "filter_level": "low",
#         "lang": "en"
#       },
#       "is_quote_status": false,
#       "quote_count": 0,
#       "reply_count": 0,
#       "retweet_count": 0,
#       "favorite_count": 0,
#       "entities": {
#         "hashtags": [],
#         "urls": [
#           {
#             "url": "https://t.co/xOkzBGD2lB",
#             "expanded_url": "https://cnn.it/2S8rapt",
#             "display_url": "cnn.it/2S8rapt",
#             "indices": [
#               100,
#               123
#             ]
#           }
#         ],
#         "user_mentions": [
#           {
#             "screen_name": "CNN",
#             "name": "CNN",
#             "id": 759251,
#             "id_str": "759251",
#             "indices": [
#               3,
#               7
#             ]
#           }
#         ],
#         "symbols": []
#       },
#       "favorited": false,
#       "retweeted": false,
#       "possibly_sensitive": false,
#       "filter_level": "low",
#       "lang": "en",
#       "matching_rules": [
#         {
#           "tag": null
#         }
#       ]
#     },
#     {
#       "created_at": "Fri Jan 31 23:58:59 +0000 2020",
#       "id": 1223395282538369024,
#       "id_str": "1223395282538369024",
#       "text": "RT @JaneLytv: 43. Zero Hedge, a pro-Trump website, has doxxed a Chinese scientist it falsely connected to the spread of coronavirus. The si\u2026",
#       "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#       "truncated": false,
#       "in_reply_to_status_id": null,
#       "in_reply_to_status_id_str": null,
#       "in_reply_to_user_id": null,
#       "in_reply_to_user_id_str": null,
#       "in_reply_to_screen_name": null,
#       "user": {
#         "id": 262334207,
#         "id_str": "262334207",
#         "name": "Eric Opperman",
#         "screen_name": "EjOpperman",
#         "location": null,
#         "url": null,
#         "description": "83rd Floor World Trade Center North Tower",
#         "translator_type": "none",
#         "protected": false,
#         "verified": false,
#         "followers_count": 127,
#         "friends_count": 564,
#         "listed_count": 3,
#         "favourites_count": 2374,
#         "statuses_count": 8602,
#         "created_at": "Mon Mar 07 21:13:41 +0000 2011",
#         "utc_offset": null,
#         "time_zone": null,
#         "geo_enabled": false,
#         "lang": null,
#         "contributors_enabled": false,
#         "is_translator": false,
#         "profile_background_color": "C0DEED",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": false,
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/421474053187063808/70f55gTl_normal.jpeg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/421474053187063808/70f55gTl_normal.jpeg",
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/262334207/1389326376",
#         "default_profile": true,
#         "default_profile_image": false,
#         "following": null,
#         "follow_request_sent": null,
#         "notifications": null
#       },
#       "geo": null,
#       "coordinates": null,
#       "place": null,
#       "contributors": null,
#       "retweeted_status": {
#         "created_at": "Fri Jan 31 22:19:00 +0000 2020",
#         "id": 1223370119109337090,
#         "id_str": "1223370119109337090",
#         "text": "43. Zero Hedge, a pro-Trump website, has doxxed a Chinese scientist it falsely connected to the spread of coronavir\u2026 https://t.co/5toOCUQCUS",
#         "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#         "truncated": true,
#         "in_reply_to_status_id": 1223364112329138176,
#         "in_reply_to_status_id_str": "1223364112329138176",
#         "in_reply_to_user_id": 65284273,
#         "in_reply_to_user_id_str": "65284273",
#         "in_reply_to_screen_name": "JaneLytv",
#         "user": {
#           "id": 65284273,
#           "id_str": "65284273",
#           "name": "Jane Lytvynenko",
#           "screen_name": "JaneLytv",
#           "location": "Toronto, Ontario",
#           "url": "https://www.buzzfeednews.com/article/janelytvynenko",
#           "description": "senior reporter w focus on disinfo, online investigations \u2022 Signal: +1 647 372 5343 \u2022 jane.lytvynenko@buzzfeed.com \u2022 janelytv@protonmail.com \u2022  DMs always open",
#           "translator_type": "none",
#           "protected": false,
#           "verified": true,
#           "followers_count": 55570,
#           "friends_count": 5840,
#           "listed_count": 1050,
#           "favourites_count": 30289,
#           "statuses_count": 12507,
#           "created_at": "Thu Aug 13 05:20:45 +0000 2009",
#           "utc_offset": null,
#           "time_zone": null,
#           "geo_enabled": false,
#           "lang": null,
#           "contributors_enabled": false,
#           "is_translator": false,
#           "profile_background_color": "050505",
#           "profile_background_image_url": "http://abs.twimg.com/images/themes/theme9/bg.gif",
#           "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme9/bg.gif",
#           "profile_background_tile": true,
#           "profile_link_color": "ABB8C2",
#           "profile_sidebar_border_color": "000000",
#           "profile_sidebar_fill_color": "C2C2C2",
#           "profile_text_color": "362720",
#           "profile_use_background_image": true,
#           "profile_image_url": "http://pbs.twimg.com/profile_images/1165700602334208000/M9RCv3YZ_normal.jpg",
#           "profile_image_url_https": "https://pbs.twimg.com/profile_images/1165700602334208000/M9RCv3YZ_normal.jpg",
#           "profile_banner_url": "https://pbs.twimg.com/profile_banners/65284273/1580237774",
#           "default_profile": false,
#           "default_profile_image": false,
#           "following": null,
#           "follow_request_sent": null,
#           "notifications": null
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "extended_tweet": {
#           "full_text": "43. Zero Hedge, a pro-Trump website, has doxxed a Chinese scientist it falsely connected to the spread of coronavirus. The site is trying to portray the virus as a real-life Resident Evil scenario. That's far from the truth, @broderick reports: \n\nhttps://t.co/ByTAanaT8r",
#           "display_text_range": [
#             0,
#             270
#           ],
#           "entities": {
#             "hashtags": [],
#             "urls": [
#               {
#                 "url": "https://t.co/ByTAanaT8r",
#                 "expanded_url": "https://www.buzzfeednews.com/article/ryanhatesthis/a-pro-trump-blog-has-doxed-a-chinese-scientist-it-falsely",
#                 "display_url": "buzzfeednews.com/article/ryanha\u2026",
#                 "indices": [
#                   247,
#                   270
#                 ]
#               }
#             ],
#             "user_mentions": [
#               {
#                 "screen_name": "broderick",
#                 "name": "Ryan Broderick",
#                 "id": 18205531,
#                 "id_str": "18205531",
#                 "indices": [
#                   225,
#                   235
#                 ]
#               }
#             ],
#             "symbols": []
#           }
#         },
#         "quote_count": 25,
#         "reply_count": 37,
#         "retweet_count": 50,
#         "favorite_count": 77,
#         "entities": {
#           "hashtags": [],
#           "urls": [
#             {
#               "url": "https://t.co/5toOCUQCUS",
#               "expanded_url": "https://twitter.com/i/web/status/1223370119109337090",
#               "display_url": "twitter.com/i/web/status/1\u2026",
#               "indices": [
#                 117,
#                 140
#               ]
#             }
#           ],
#           "user_mentions": [],
#           "symbols": []
#         },
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "filter_level": "low",
#         "lang": "en"
#       },
#       "is_quote_status": false,
#       "quote_count": 0,
#       "reply_count": 0,
#       "retweet_count": 0,
#       "favorite_count": 0,
#       "entities": {
#         "hashtags": [],
#         "urls": [],
#         "user_mentions": [
#           {
#             "screen_name": "JaneLytv",
#             "name": "Jane Lytvynenko",
#             "id": 65284273,
#             "id_str": "65284273",
#             "indices": [
#               3,
#               12
#             ]
#           }
#         ],
#         "symbols": []
#       },
#       "favorited": false,
#       "retweeted": false,
#       "filter_level": "low",
#       "lang": "en",
#       "matching_rules": [
#         {
#           "tag": null
#         }
#       ]
#     },
#     {
#       "created_at": "Fri Jan 31 23:58:59 +0000 2020",
#       "id": 1223395281905111040,
#       "id_str": "1223395281905111040",
#       "text": "RT @skarlamangla: This flu season has killed 10,000 Americans. Coronavirus hasn\u2019t killed anyone in the US. \n\nmy latest: https://t.co/eCyeGG\u2026",
#       "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#       "truncated": false,
#       "in_reply_to_status_id": null,
#       "in_reply_to_status_id_str": null,
#       "in_reply_to_user_id": null,
#       "in_reply_to_user_id_str": null,
#       "in_reply_to_screen_name": null,
#       "user": {
#         "id": 2451840349,
#         "id_str": "2451840349",
#         "name": "Natasha Lightfoot \ud83c\udde6\ud83c\uddec",
#         "screen_name": "njlightfoot",
#         "location": "nyc & antigua",
#         "url": "https://www.dukeupress.edu/Troubling-Freedom/?viewby=title",
#         "description": "historian. geek. pop culture junkie. fashionista. caribbean queen. bronx broad. mother. daughter. fighter. thinker.",
#         "translator_type": "none",
#         "protected": false,
#         "verified": false,
#         "followers_count": 4626,
#         "friends_count": 1932,
#         "listed_count": 109,
#         "favourites_count": 55066,
#         "statuses_count": 26248,
#         "created_at": "Fri Apr 18 19:16:32 +0000 2014",
#         "utc_offset": null,
#         "time_zone": null,
#         "geo_enabled": false,
#         "lang": null,
#         "contributors_enabled": false,
#         "is_translator": false,
#         "profile_background_color": "C0DEED",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": false,
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1120781037196460032/zOE-0TBE_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1120781037196460032/zOE-0TBE_normal.jpg",
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/2451840349/1465195761",
#         "default_profile": true,
#         "default_profile_image": false,
#         "following": null,
#         "follow_request_sent": null,
#         "notifications": null
#       },
#       "geo": null,
#       "coordinates": null,
#       "place": null,
#       "contributors": null,
#       "retweeted_status": {
#         "created_at": "Fri Jan 31 21:08:39 +0000 2020",
#         "id": 1223352415262400512,
#         "id_str": "1223352415262400512",
#         "text": "This flu season has killed 10,000 Americans. Coronavirus hasn\u2019t killed anyone in the US. \n\nmy latest: https://t.co/eCyeGG8h6t",
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "truncated": false,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#           "id": 244701234,
#           "id_str": "244701234",
#           "name": "Soumya",
#           "screen_name": "skarlamangla",
#           "location": "Los Angeles, California",
#           "url": "http://www.latimes.com/la-bio-soumya-karlamangla-staff.html",
#           "description": "health reporter at the Los Angeles Times. former rosalynn carter mental health fellow. call me beep me if you want to reach me: soumya.karlamangla@latimes.com",
#           "translator_type": "none",
#           "protected": false,
#           "verified": true,
#           "followers_count": 16570,
#           "friends_count": 2757,
#           "listed_count": 583,
#           "favourites_count": 12873,
#           "statuses_count": 12156,
#           "created_at": "Sat Jan 29 23:03:33 +0000 2011",
#           "utc_offset": null,
#           "time_zone": null,
#           "geo_enabled": true,
#           "lang": null,
#           "contributors_enabled": false,
#           "is_translator": false,
#           "profile_background_color": "2E0000",
#           "profile_background_image_url": "http://abs.twimg.com/images/themes/theme7/bg.gif",
#           "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme7/bg.gif",
#           "profile_background_tile": true,
#           "profile_link_color": "D4513F",
#           "profile_sidebar_border_color": "929C7A",
#           "profile_sidebar_fill_color": "958C6B",
#           "profile_text_color": "BD9679",
#           "profile_use_background_image": true,
#           "profile_image_url": "http://pbs.twimg.com/profile_images/1019061820068261890/UKFbU45L_normal.jpg",
#           "profile_image_url_https": "https://pbs.twimg.com/profile_images/1019061820068261890/UKFbU45L_normal.jpg",
#           "profile_banner_url": "https://pbs.twimg.com/profile_banners/244701234/1484020302",
#           "default_profile": false,
#           "default_profile_image": false,
#           "following": null,
#           "follow_request_sent": null,
#           "notifications": null
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": {
#           "id": "3b77caf94bfc81fe",
#           "url": "https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json",
#           "place_type": "city",
#           "name": "Los Angeles",
#           "full_name": "Los Angeles, CA",
#           "country_code": "US",
#           "country": "United States",
#           "bounding_box": {
#             "type": "Polygon",
#             "coordinates": [
#               [
#                 [
#                   -118.668404,
#                   33.704538
#                 ],
#                 [
#                   -118.668404,
#                   34.337041
#                 ],
#                 [
#                   -118.155409,
#                   34.337041
#                 ],
#                 [
#                   -118.155409,
#                   33.704538
#                 ]
#               ]
#             ]
#           },
#           "attributes": {}
#         },
#         "contributors": null,
#         "is_quote_status": false,
#         "quote_count": 43,
#         "reply_count": 55,
#         "retweet_count": 488,
#         "favorite_count": 848,
#         "entities": {
#           "hashtags": [],
#           "urls": [
#             {
#               "url": "https://t.co/eCyeGG8h6t",
#               "expanded_url": "https://www.latimes.com/california/story/2020-01-31/flu-coronavirus",
#               "display_url": "latimes.com/california/sto\u2026",
#               "indices": [
#                 102,
#                 125
#               ]
#             }
#           ],
#           "user_mentions": [],
#           "symbols": []
#         },
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "filter_level": "low",
#         "lang": "en"
#       },
#       "is_quote_status": false,
#       "quote_count": 0,
#       "reply_count": 0,
#       "retweet_count": 0,
#       "favorite_count": 0,
#       "entities": {
#         "hashtags": [],
#         "urls": [],
#         "user_mentions": [
#           {
#             "screen_name": "skarlamangla",
#             "name": "Soumya",
#             "id": 244701234,
#             "id_str": "244701234",
#             "indices": [
#               3,
#               16
#             ]
#           }
#         ],
#         "symbols": []
#       },
#       "favorited": false,
#       "retweeted": false,
#       "filter_level": "low",
#       "lang": "en",
#       "matching_rules": [
#         {
#           "tag": null
#         }
#       ]
#     },
#     {
#       "created_at": "Fri Jan 31 23:58:59 +0000 2020",
#       "id": 1223395281804247041,
#       "id_str": "1223395281804247041",
#       "text": "RT @jamesmassola: Medical experts raise concerns about Indonesia's ability to detect novel coronavirus. The reagents - chemicals used in sp\u2026",
#       "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#       "truncated": false,
#       "in_reply_to_status_id": null,
#       "in_reply_to_status_id_str": null,
#       "in_reply_to_user_id": null,
#       "in_reply_to_user_id_str": null,
#       "in_reply_to_screen_name": null,
#       "user": {
#         "id": 513208128,
#         "id_str": "513208128",
#         "name": "Jhn",
#         "screen_name": "reallllllfanboy",
#         "location": "In a Blue Dream",
#         "url": null,
#         "description": "WINPINK, Day6 and Blue.D only",
#         "translator_type": "none",
#         "protected": false,
#         "verified": false,
#         "followers_count": 218,
#         "friends_count": 323,
#         "listed_count": 2,
#         "favourites_count": 2380,
#         "statuses_count": 18857,
#         "created_at": "Sat Mar 03 14:07:21 +0000 2012",
#         "utc_offset": null,
#         "time_zone": null,
#         "geo_enabled": true,
#         "lang": null,
#         "contributors_enabled": false,
#         "is_translator": false,
#         "profile_background_color": "C0DEED",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": true,
#         "profile_link_color": "0084B4",
#         "profile_sidebar_border_color": "FFFFFF",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1300054944846766080/AOwAfJBK_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1300054944846766080/AOwAfJBK_normal.jpg",
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/513208128/1587264620",
#         "default_profile": false,
#         "default_profile_image": false,
#         "following": null,
#         "follow_request_sent": null,
#         "notifications": null
#       },
#       "geo": null,
#       "coordinates": null,
#       "place": null,
#       "contributors": null,
#       "retweeted_status": {
#         "created_at": "Fri Jan 31 05:06:49 +0000 2020",
#         "id": 1223110362515439617,
#         "id_str": "1223110362515439617",
#         "text": "Medical experts raise concerns about Indonesia's ability to detect novel coronavirus. The reagents - chemicals used\u2026 https://t.co/9Gd3ZeItaP",
#         "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#         "truncated": true,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#           "id": 17774061,
#           "id_str": "17774061",
#           "name": "James Massola",
#           "screen_name": "jamesmassola",
#           "location": "Canberra, Australian Capital Territory",
#           "url": "https://www.smh.com.au/by/james-massola-hvf20",
#           "description": "SE-Asia, NZ for @smh @theage. Previously chief political corro, Canberra. Author, Great Cave Rescue. @melbournefc WA +628119846381 or jmassola@smh.com.au",
#           "translator_type": "none",
#           "protected": false,
#           "verified": true,
#           "followers_count": 41283,
#           "friends_count": 2203,
#           "listed_count": 868,
#           "favourites_count": 4271,
#           "statuses_count": 43084,
#           "created_at": "Mon Dec 01 07:29:01 +0000 2008",
#           "utc_offset": null,
#           "time_zone": null,
#           "geo_enabled": true,
#           "lang": null,
#           "contributors_enabled": false,
#           "is_translator": false,
#           "profile_background_color": "0099B9",
#           "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#           "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#           "profile_background_tile": false,
#           "profile_link_color": "0099B9",
#           "profile_sidebar_border_color": "FFFFFF",
#           "profile_sidebar_fill_color": "DDFFCC",
#           "profile_text_color": "333333",
#           "profile_use_background_image": true,
#           "profile_image_url": "http://pbs.twimg.com/profile_images/987346459228958720/QK7LjTok_normal.jpg",
#           "profile_image_url_https": "https://pbs.twimg.com/profile_images/987346459228958720/QK7LjTok_normal.jpg",
#           "profile_banner_url": "https://pbs.twimg.com/profile_banners/17774061/1539009710",
#           "default_profile": false,
#           "default_profile_image": false,
#           "following": null,
#           "follow_request_sent": null,
#           "notifications": null
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "extended_tweet": {
#           "full_text": "Medical experts raise concerns about Indonesia's ability to detect novel coronavirus. The reagents - chemicals used in specific testing kits to identify the Wuhan, or novel, coronavirus - are not yet in the country.  They'll  arrive in next few days https://t.co/9Oa10AksJB",
#           "display_text_range": [
#             0,
#             273
#           ],
#           "entities": {
#             "hashtags": [],
#             "urls": [
#               {
#                 "url": "https://t.co/9Oa10AksJB",
#                 "expanded_url": "http://bit.ly/2S2TzNL",
#                 "display_url": "bit.ly/2S2TzNL",
#                 "indices": [
#                   250,
#                   273
#                 ]
#               }
#             ],
#             "user_mentions": [],
#             "symbols": []
#           }
#         },
#         "quote_count": 1127,
#         "reply_count": 126,
#         "retweet_count": 3167,
#         "favorite_count": 2848,
#         "entities": {
#           "hashtags": [],
#           "urls": [
#             {
#               "url": "https://t.co/9Gd3ZeItaP",
#               "expanded_url": "https://twitter.com/i/web/status/1223110362515439617",
#               "display_url": "twitter.com/i/web/status/1\u2026",
#               "indices": [
#                 117,
#                 140
#               ]
#             }
#           ],
#           "user_mentions": [],
#           "symbols": []
#         },
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "filter_level": "low",
#         "lang": "en"
#       },
#       "is_quote_status": false,
#       "quote_count": 0,
#       "reply_count": 0,
#       "retweet_count": 0,
#       "favorite_count": 0,
#       "entities": {
#         "hashtags": [],
#         "urls": [],
#         "user_mentions": [
#           {
#             "screen_name": "jamesmassola",
#             "name": "James Massola",
#             "id": 17774061,
#             "id_str": "17774061",
#             "indices": [
#               3,
#               16
#             ]
#           }
#         ],
#         "symbols": []
#       },
#       "favorited": false,
#       "retweeted": false,
#       "filter_level": "low",
#       "lang": "en",
#       "matching_rules": [
#         {
#           "tag": null
#         }
#       ]
#     },
#     {
#       "created_at": "Fri Jan 31 23:58:59 +0000 2020",
#       "id": 1223395281623973889,
#       "id_str": "1223395281623973889",
#       "text": "RT @popplioikawa: the flu: *results in 500,000 hospitalizations and 30,000 deaths a year in the usa*\namericans: *don't even get the fucking\u2026",
#       "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#       "truncated": false,
#       "in_reply_to_status_id": null,
#       "in_reply_to_status_id_str": null,
#       "in_reply_to_user_id": null,
#       "in_reply_to_user_id_str": null,
#       "in_reply_to_screen_name": null,
#       "user": {
#         "id": 993138436667314176,
#         "id_str": "993138436667314176",
#         "name": "(\u0e07'\u0300-'\u0301)\u0e07 \u2077 D2",
#         "screen_name": "jkcupoftea",
#         "location": null,
#         "url": null,
#         "description": "\u201cwin.lose. I don\u2019t care because at the end of the day I still have this face so who\u2019s the real winner here ?\u201d -jin | Night Mode On \ud83c\udf11 | Pisces \ud83d\udda4",
#         "translator_type": "none",
#         "protected": false,
#         "verified": false,
#         "followers_count": 318,
#         "friends_count": 263,
#         "listed_count": 1,
#         "favourites_count": 9762,
#         "statuses_count": 26128,
#         "created_at": "Sun May 06 14:40:29 +0000 2018",
#         "utc_offset": null,
#         "time_zone": null,
#         "geo_enabled": false,
#         "lang": null,
#         "contributors_enabled": false,
#         "is_translator": false,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": "",
#         "profile_background_image_url_https": "",
#         "profile_background_tile": false,
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1292839713653559296/CutoCal0_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1292839713653559296/CutoCal0_normal.jpg",
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/993138436667314176/1595175616",
#         "default_profile": true,
#         "default_profile_image": false,
#         "following": null,
#         "follow_request_sent": null,
#         "notifications": null
#       },
#       "geo": null,
#       "coordinates": null,
#       "place": null,
#       "contributors": null,
#       "retweeted_status": {
#         "created_at": "Fri Jan 31 01:27:50 +0000 2020",
#         "id": 1223055252670177280,
#         "id_str": "1223055252670177280",
#         "text": "the flu: *results in 500,000 hospitalizations and 30,000 deaths a year in the usa*\namericans: *don't even get the f\u2026 https://t.co/WwPb3RAgDJ",
#         "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#         "truncated": true,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#           "id": 1030388492688224256,
#           "id_str": "1030388492688224256",
#           "name": "ph\u2606e @ n0hebi apoIogist",
#           "screen_name": "popplioikawa",
#           "location": "sorikai nation",
#           "url": null,
#           "description": "400 sons, 0 brain cells \u25c7 phee, 25, she/her, AUS. icon by @rybaris \u25c7 I don't want to be friends, sorry! RT + chatter + haikyuu + \ud83d\udd1e \u25c7 unfollow at will",
#           "translator_type": "none",
#           "protected": false,
#           "verified": false,
#           "followers_count": 8556,
#           "friends_count": 489,
#           "listed_count": 33,
#           "favourites_count": 92138,
#           "statuses_count": 61340,
#           "created_at": "Fri Aug 17 09:38:55 +0000 2018",
#           "utc_offset": null,
#           "time_zone": null,
#           "geo_enabled": false,
#           "lang": null,
#           "contributors_enabled": false,
#           "is_translator": false,
#           "profile_background_color": "000000",
#           "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#           "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#           "profile_background_tile": false,
#           "profile_link_color": "7FDBB6",
#           "profile_sidebar_border_color": "000000",
#           "profile_sidebar_fill_color": "000000",
#           "profile_text_color": "000000",
#           "profile_use_background_image": false,
#           "profile_image_url": "http://pbs.twimg.com/profile_images/1258732742298107905/cJOtNWp4_normal.jpg",
#           "profile_image_url_https": "https://pbs.twimg.com/profile_images/1258732742298107905/cJOtNWp4_normal.jpg",
#           "profile_banner_url": "https://pbs.twimg.com/profile_banners/1030388492688224256/1562213244",
#           "default_profile": false,
#           "default_profile_image": false,
#           "following": null,
#           "follow_request_sent": null,
#           "notifications": null
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "extended_tweet": {
#           "full_text": "the flu: *results in 500,000 hospitalizations and 30,000 deaths a year in the usa*\namericans: *don't even get the fucking flu shot consistently*\ncoronavirus: *resulted in 0 deaths in any country outside of china*\namericans: *HYSTERICALLY USING IT AS AN EXCUSE TO BE ANTI-CHINESE*",
#           "display_text_range": [
#             0,
#             279
#           ],
#           "entities": {
#             "hashtags": [],
#             "urls": [],
#             "user_mentions": [],
#             "symbols": []
#           }
#         },
#         "quote_count": 443,
#         "reply_count": 285,
#         "retweet_count": 32681,
#         "favorite_count": 113250,
#         "entities": {
#           "hashtags": [],
#           "urls": [
#             {
#               "url": "https://t.co/WwPb3RAgDJ",
#               "expanded_url": "https://twitter.com/i/web/status/1223055252670177280",
#               "display_url": "twitter.com/i/web/status/1\u2026",
#               "indices": [
#                 117,
#                 140
#               ]
#             }
#           ],
#           "user_mentions": [],
#           "symbols": []
#         },
#         "favorited": false,
#         "retweeted": false,
#         "filter_level": "low",
#         "lang": "en"
#       },
#       "is_quote_status": false,
#       "quote_count": 0,
#       "reply_count": 0,
#       "retweet_count": 0,
#       "favorite_count": 0,
#       "entities": {
#         "hashtags": [],
#         "urls": [],
#         "user_mentions": [
#           {
#             "screen_name": "popplioikawa",
#             "name": "ph\u2606e @ n0hebi apoIogist",
#             "id": 1030388492688224256,
#             "id_str": "1030388492688224256",
#             "indices": [
#               3,
#               16
#             ]
#           }
#         ],
#         "symbols": []
#       },
#       "favorited": false,
#       "retweeted": false,
#       "filter_level": "low",
#       "lang": "en",
#       "matching_rules": [
#         {
#           "tag": null
#         }
#       ]
#     },
#     {
#       "created_at": "Fri Jan 31 23:58:59 +0000 2020",
#       "id": 1223395281229766658,
#       "id_str": "1223395281229766658",
#       "text": "RT @LaLaRueFrench75: @MaryamHenein @BusyDrT @bloody_scandal Spy games: Could this be a deep state production rather than an act of war by a\u2026",
#       "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#       "truncated": false,
#       "in_reply_to_status_id": null,
#       "in_reply_to_status_id_str": null,
#       "in_reply_to_user_id": null,
#       "in_reply_to_user_id_str": null,
#       "in_reply_to_screen_name": null,
#       "user": {
#         "id": 3385997379,
#         "id_str": "3385997379",
#         "name": "Ph@rm@Owns@meric@",
#         "screen_name": "draintheswamp55",
#         "location": null,
#         "url": null,
#         "description": "Retweets do NOT represent views",
#         "translator_type": "none",
#         "protected": false,
#         "verified": false,
#         "followers_count": 3398,
#         "friends_count": 4873,
#         "listed_count": 58,
#         "favourites_count": 229951,
#         "statuses_count": 184083,
#         "created_at": "Tue Jul 21 16:25:49 +0000 2015",
#         "utc_offset": null,
#         "time_zone": null,
#         "geo_enabled": true,
#         "lang": null,
#         "contributors_enabled": false,
#         "is_translator": false,
#         "profile_background_color": "000000",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": false,
#         "profile_link_color": "1B95E0",
#         "profile_sidebar_border_color": "000000",
#         "profile_sidebar_fill_color": "000000",
#         "profile_text_color": "000000",
#         "profile_use_background_image": false,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/858379291536625665/4EQqrYRZ_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/858379291536625665/4EQqrYRZ_normal.jpg",
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/3385997379/1493488547",
#         "default_profile": false,
#         "default_profile_image": false,
#         "following": null,
#         "follow_request_sent": null,
#         "notifications": null
#       },
#       "geo": null,
#       "coordinates": null,
#       "place": null,
#       "contributors": null,
#       "retweeted_status": {
#         "created_at": "Fri Jan 31 18:16:08 +0000 2020",
#         "id": 1223309001699446784,
#         "id_str": "1223309001699446784",
#         "text": "@MaryamHenein @BusyDrT @bloody_scandal Spy games: Could this be a deep state production rather than an act of war b\u2026 https://t.co/jVOlaghlZp",
#         "display_text_range": [
#           39,
#           140
#         ],
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "truncated": true,
#         "in_reply_to_status_id": 1223305364633866241,
#         "in_reply_to_status_id_str": "1223305364633866241",
#         "in_reply_to_user_id": 73928056,
#         "in_reply_to_user_id_str": "73928056",
#         "in_reply_to_screen_name": "LaLaRueFrench75",
#         "user": {
#           "id": 73928056,
#           "id_str": "73928056",
#           "name": "\ud83c\uddfa\ud83c\uddf8P\u0361\u035cR\u0361\u035cA\u0361\u035cY\u0361\u035c\ud83d\ude4f\ud83c\udffd",
#           "screen_name": "LaLaRueFrench75",
#           "location": "San Francisco is My Disco",
#           "url": "https://music.apple.com/us/artist/laura-larue/354606381",
#           "description": "Former Billboard Charting EDM Artist\ud83c\udfa4supporting MED FREEDOM & RFK Jr\u2019s quest for VAX accountability & vax safety. SEE VAXXED2! Read #PlagueOfCorruption",
#           "translator_type": "none",
#           "protected": false,
#           "verified": false,
#           "followers_count": 37773,
#           "friends_count": 31663,
#           "listed_count": 1430,
#           "favourites_count": 122819,
#           "statuses_count": 162471,
#           "created_at": "Sun Sep 13 17:25:57 +0000 2009",
#           "utc_offset": null,
#           "time_zone": null,
#           "geo_enabled": false,
#           "lang": null,
#           "contributors_enabled": false,
#           "is_translator": false,
#           "profile_background_color": "131516",
#           "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#           "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#           "profile_background_tile": true,
#           "profile_link_color": "333333",
#           "profile_sidebar_border_color": "000000",
#           "profile_sidebar_fill_color": "EFEFEF",
#           "profile_text_color": "009999",
#           "profile_use_background_image": true,
#           "profile_image_url": "http://pbs.twimg.com/profile_images/1235515233512243205/xpajxy5X_normal.jpg",
#           "profile_image_url_https": "https://pbs.twimg.com/profile_images/1235515233512243205/xpajxy5X_normal.jpg",
#           "profile_banner_url": "https://pbs.twimg.com/profile_banners/73928056/1566059610",
#           "default_profile": false,
#           "default_profile_image": false,
#           "following": null,
#           "follow_request_sent": null,
#           "notifications": null
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "extended_tweet": {
#           "full_text": "@MaryamHenein @BusyDrT @bloody_scandal Spy games: Could this be a deep state production rather than an act of war by a single gvt? As the adage goes, follow the money. We\u2019re looking at a souped up cold that the media\u2019s sensationalizing, even tho more ppl die every yr from flu &amp; pharmaceuticals! https://t.co/IpkomH4aQ9",
#           "display_text_range": [
#             39,
#             323
#           ],
#           "entities": {
#             "hashtags": [],
#             "urls": [
#               {
#                 "url": "https://t.co/IpkomH4aQ9",
#                 "expanded_url": "https://www.zerohedge.com/geopolitical/did-china-steal-coronavirus-canada-and-weaponize-it",
#                 "display_url": "zerohedge.com/geopolitical/d\u2026",
#                 "indices": [
#                   300,
#                   323
#                 ]
#               }
#             ],
#             "user_mentions": [
#               {
#                 "screen_name": "MaryamHenein",
#                 "name": "Maryam Henein/ #Shadowbanned (aka BeeLady)/ 6%",
#                 "id": 80924518,
#                 "id_str": "80924518",
#                 "indices": [
#                   0,
#                   13
#                 ]
#               },
#               {
#                 "screen_name": "BusyDrT",
#                 "name": "Dr Sherri Tenpenny",
#                 "id": 35013035,
#                 "id_str": "35013035",
#                 "indices": [
#                   14,
#                   22
#                 ]
#               },
#               {
#                 "screen_name": "bloody_scandal",
#                 "name": "Bloody Scandal",
#                 "id": 771556891109437440,
#                 "id_str": "771556891109437440",
#                 "indices": [
#                   23,
#                   38
#                 ]
#               }
#             ],
#             "symbols": []
#           }
#         },
#         "quote_count": 1,
#         "reply_count": 2,
#         "retweet_count": 9,
#         "favorite_count": 17,
#         "entities": {
#           "hashtags": [],
#           "urls": [
#             {
#               "url": "https://t.co/jVOlaghlZp",
#               "expanded_url": "https://twitter.com/i/web/status/1223309001699446784",
#               "display_url": "twitter.com/i/web/status/1\u2026",
#               "indices": [
#                 117,
#                 140
#               ]
#             }
#           ],
#           "user_mentions": [
#             {
# ...
#             "source_status_id_str": "1222897218098626563",
#             "source_user_id": 491690296,
#             "source_user_id_str": "491690296"
#           }
#         ]
#       },
#       "favorited": false,
#       "retweeted": false,
#       "possibly_sensitive": false,
#       "filter_level": "low",
#       "lang": "en",
#       "matching_rules": [
#         {
#           "tag": null
#         }
#       ]
#     },
#     {
#       "created_at": "Fri Jan 31 23:58:46 +0000 2020",
#       "id": 1223395227685326854,
#       "id_str": "1223395227685326854",
#       "text": "RT @allkpopBuzz: Popular Youtube channel apologizes after pulling a Coronavirus hidden camera prank https://t.co/STY3s7Dk9F https://t.co/Qw\u2026",
#       "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#       "truncated": false,
#       "in_reply_to_status_id": null,
#       "in_reply_to_status_id_str": null,
#       "in_reply_to_user_id": null,
#       "in_reply_to_user_id_str": null,
#       "in_reply_to_screen_name": null,
#       "user": {
#         "id": 981034128039645184,
#         "id_str": "981034128039645184",
#         "name": "Seeja",
#         "screen_name": "Seeja9",
#         "location": null,
#         "url": null,
#         "description": null,
#         "translator_type": "none",
#         "protected": false,
#         "verified": false,
#         "followers_count": 0,
#         "friends_count": 49,
#         "listed_count": 0,
#         "favourites_count": 2712,
#         "statuses_count": 4174,
#         "created_at": "Tue Apr 03 05:02:17 +0000 2018",
#         "utc_offset": null,
#         "time_zone": null,
#         "geo_enabled": false,
#         "lang": null,
#         "contributors_enabled": false,
#         "is_translator": false,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": "",
#         "profile_background_image_url_https": "",
#         "profile_background_tile": false,
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "profile_image_url": "http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#         "profile_image_url_https": "https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#         "default_profile": true,
#         "default_profile_image": false,
#         "following": null,
#         "follow_request_sent": null,
#         "notifications": null
#       },
#       "geo": null,
#       "coordinates": null,
#       "place": null,
#       "contributors": null,
#       "retweeted_status": {
#         "created_at": "Fri Jan 31 22:29:46 +0000 2020",
#         "id": 1223372828361314315,
#         "id_str": "1223372828361314315",
#         "text": "Popular Youtube channel apologizes after pulling a Coronavirus hidden camera prank https://t.co/STY3s7Dk9F https://t.co/Qw9EUP3Rzp",
#         "display_text_range": [
#           0,
#           106
#         ],
#         "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#         "truncated": false,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#           "id": 2561956273,
#           "id_str": "2561956273",
#           "name": "allkpop Buzz",
#           "screen_name": "allkpopBuzz",
#           "location": "Ridgefield Park, NJ",
#           "url": "http://www.allkpop.com",
#           "description": "The latest Buzz and Trending stories from Korea",
#           "translator_type": "none",
#           "protected": false,
#           "verified": false,
#           "followers_count": 39637,
#           "friends_count": 14,
#           "listed_count": 106,
#           "favourites_count": 29,
#           "statuses_count": 2318,
#           "created_at": "Wed Jun 11 19:19:32 +0000 2014",
#           "utc_offset": null,
#           "time_zone": null,
#           "geo_enabled": false,
#           "lang": null,
#           "contributors_enabled": false,
#           "is_translator": false,
#           "profile_background_color": "FFFFFF",
#           "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#           "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#           "profile_background_tile": false,
#           "profile_link_color": "FF0000",
#           "profile_sidebar_border_color": "FF0000",
#           "profile_sidebar_fill_color": "000000",
#           "profile_text_color": "ECE5CE",
#           "profile_use_background_image": true,
#           "profile_image_url": "http://pbs.twimg.com/profile_images/477174075475775488/JbrchgE5_normal.png",
#           "profile_image_url_https": "https://pbs.twimg.com/profile_images/477174075475775488/JbrchgE5_normal.png",
#           "profile_banner_url": "https://pbs.twimg.com/profile_banners/2561956273/1402602171",
#           "default_profile": false,
#           "default_profile_image": false,
#           "following": null,
#           "follow_request_sent": null,
#           "notifications": null
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "quote_count": 35,
#         "reply_count": 20,
#         "retweet_count": 75,
#         "favorite_count": 720,
#         "entities": {
#           "hashtags": [],
#           "urls": [
#             {
#               "url": "https://t.co/STY3s7Dk9F",
#               "expanded_url": "https://www.allkpop.com/article/2020/01/popular-youtube-channel-apologizes-after-pulling-a-coronavirus-hidden-camera-prank",
#               "display_url": "allkpop.com/article/2020/0\u2026",
#               "indices": [
#                 83,
#                 106
#               ]
#             }
#           ],
#           "user_mentions": [],
#           "symbols": [],
#           "media": [
#             {
#               "id": 1223372818588618754,
#               "id_str": "1223372818588618754",
#               "indices": [
#                 107,
#                 130
#               ],
#               "media_url": "http://pbs.twimg.com/media/EPpLGMfX0AIOfi2.jpg",
#               "media_url_https": "https://pbs.twimg.com/media/EPpLGMfX0AIOfi2.jpg",
#               "url": "https://t.co/Qw9EUP3Rzp",
#               "display_url": "pic.twitter.com/Qw9EUP3Rzp",
#               "expanded_url": "https://twitter.com/allkpopBuzz/status/1223372828361314315/photo/1",
#               "type": "photo",
#               "sizes": {
#                 "thumb": {
#                   "w": 150,
#                   "h": 150,
#                   "resize": "crop"
#                 },
#                 "small": {
#                   "w": 680,
#                   "h": 383,
#                   "resize": "fit"
#                 },
#                 "large": {
#                   "w": 1920,
#                   "h": 1080,
#                   "resize": "fit"
#                 },
#                 "medium": {
#                   "w": 1200,
#                   "h": 675,
#                   "resize": "fit"
#                 }
#               }
#             }
#           ]
#         },
#         "extended_entities": {
#           "media": [
#             {
#               "id": 1223372818588618754,
#               "id_str": "1223372818588618754",
#               "indices": [
#                 107,
#                 130
#               ],
#               "media_url": "http://pbs.twimg.com/media/EPpLGMfX0AIOfi2.jpg",
#               "media_url_https": "https://pbs.twimg.com/media/EPpLGMfX0AIOfi2.jpg",
#               "url": "https://t.co/Qw9EUP3Rzp",
#               "display_url": "pic.twitter.com/Qw9EUP3Rzp",
#               "expanded_url": "https://twitter.com/allkpopBuzz/status/1223372828361314315/photo/1",
#               "type": "photo",
#               "sizes": {
#                 "thumb": {
#                   "w": 150,
#                   "h": 150,
#                   "resize": "crop"
#                 },
#                 "small": {
#                   "w": 680,
#                   "h": 383,
#                   "resize": "fit"
#                 },
#                 "large": {
#                   "w": 1920,
#                   "h": 1080,
#                   "resize": "fit"
#                 },
#                 "medium": {
#                   "w": 1200,
#                   "h": 675,
#                   "resize": "fit"
#                 }
#               }
#             }
#           ]
#         },
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "filter_level": "low",
#         "lang": "en"
#       },
#       "is_quote_status": false,
#       "quote_count": 0,
#       "reply_count": 0,
#       "retweet_count": 0,
#       "favorite_count": 0,
#       "entities": {
#         "hashtags": [],
#         "urls": [
#           {
#             "url": "https://t.co/STY3s7Dk9F",
#             "expanded_url": "https://www.allkpop.com/article/2020/01/popular-youtube-channel-apologizes-after-pulling-a-coronavirus-hidden-camera-prank",
#             "display_url": "allkpop.com/article/2020/0\u2026",
#             "indices": [
#               100,
#               123
#             ]
#           }
#         ],
#         "user_mentions": [
#           {
#             "screen_name": "allkpopBuzz",
#             "name": "allkpop Buzz",
#             "id": 2561956273,
#             "id_str": "2561956273",
#             "indices": [
#               3,
#               15
#             ]
#           }
#         ],
#         "symbols": []
#       },
#       "favorited": false,
#       "retweeted": false,
#       "possibly_sensitive": false,
#       "filter_level": "low",
#       "lang": "en",
#       "matching_rules": [
#         {
#           "tag": null
#         }
#       ]
#     },
#     {
#       "created_at": "Fri Jan 31 23:58:46 +0000 2020",
#       "id": 1223395227672698880,
#       "id_str": "1223395227672698880",
#       "text": "RT @chanibains_: This boy told me he might be going jail next month and I replied saying at least he\u2019s safe from catching coronavirus and h\u2026",
#       "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#       "truncated": false,
#       "in_reply_to_status_id": null,
#       "in_reply_to_status_id_str": null,
#       "in_reply_to_user_id": null,
#       "in_reply_to_user_id_str": null,
#       "in_reply_to_screen_name": null,
#       "user": {
#         "id": 1064855216653250562,
#         "id_str": "1064855216653250562",
#         "name": "yourfaveejem\ud83c\uddfa\ud83c\uddec",
#         "screen_name": "_jemk",
#         "location": null,
#         "url": "http://instagram.com/jemimahh._",
#         "description": "take everything i tweet with a pinch of \ud83e\uddc2",
#         "translator_type": "none",
#         "protected": false,
#         "verified": false,
#         "followers_count": 934,
#         "friends_count": 672,
#         "listed_count": 0,
#         "favourites_count": 44580,
#         "statuses_count": 14944,
#         "created_at": "Tue Nov 20 12:17:22 +0000 2018",
#         "utc_offset": null,
#         "time_zone": null,
#         "geo_enabled": false,
#         "lang": null,
#         "contributors_enabled": false,
#         "is_translator": false,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": "",
#         "profile_background_image_url_https": "",
#         "profile_background_tile": false,
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1295499678503632899/sNDNdGHZ_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1295499678503632899/sNDNdGHZ_normal.jpg",
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/1064855216653250562/1590774622",
#         "default_profile": true,
#         "default_profile_image": false,
#         "following": null,
#         "follow_request_sent": null,
#         "notifications": null
#       },
#       "geo": null,
#       "coordinates": null,
#       "place": null,
#       "contributors": null,
#       "retweeted_status": {
#         "created_at": "Fri Jan 31 19:12:07 +0000 2020",
#         "id": 1223323091373383680,
#         "id_str": "1223323091373383680",
#         "text": "This boy told me he might be going jail next month and I replied saying at least he\u2019s safe from catching coronavirus and he blocked me??",
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "truncated": false,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#           "id": 734995676,
#           "id_str": "734995676",
#           "name": "C Biz\ud83e\udd2a",
#           "screen_name": "ckbainss",
#           "location": "Midlands",
#           "url": null,
#           "description": "I\u2019m nines supporter btw | \u262c #FreeJaggiNow",
#           "translator_type": "none",
#           "protected": false,
#           "verified": false,
#           "followers_count": 4659,
#           "friends_count": 2296,
#           "listed_count": 6,
#           "favourites_count": 43136,
#           "statuses_count": 8856,
#           "created_at": "Fri Aug 03 14:44:12 +0000 2012",
#           "utc_offset": null,
#           "time_zone": null,
#           "geo_enabled": true,
#           "lang": null,
#           "contributors_enabled": false,
#           "is_translator": false,
#           "profile_background_color": "C0DEED",
#           "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#           "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#           "profile_background_tile": false,
#           "profile_link_color": "1DA1F2",
#           "profile_sidebar_border_color": "C0DEED",
#           "profile_sidebar_fill_color": "DDEEF6",
#           "profile_text_color": "333333",
#           "profile_use_background_image": true,
#           "profile_image_url": "http://pbs.twimg.com/profile_images/1292919676721340418/Wzo7qzrt_normal.jpg",
#           "profile_image_url_https": "https://pbs.twimg.com/profile_images/1292919676721340418/Wzo7qzrt_normal.jpg",
#           "profile_banner_url": "https://pbs.twimg.com/profile_banners/734995676/1592697113",
#           "default_profile": true,
#           "default_profile_image": false,
#           "following": null,
#           "follow_request_sent": null,
#           "notifications": null
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "quote_count": 2,
#         "reply_count": 7,
#         "retweet_count": 39,
#         "favorite_count": 381,
#         "entities": {
#           "hashtags": [],
#           "urls": [],
#           "user_mentions": [],
#           "symbols": []
#         },
#         "favorited": false,
#         "retweeted": false,
#         "filter_level": "low",
#         "lang": "en"
#       },
#       "is_quote_status": false,
#       "quote_count": 0,
#       "reply_count": 0,
#       "retweet_count": 0,
#       "favorite_count": 0,
#       "entities": {
#         "hashtags": [],
#         "urls": [],
#         "user_mentions": [
#           {
#             "screen_name": "chanibains_",
#             "name": null,
#             "id": null,
#             "id_str": null,
#             "indices": [
#               3,
#               15
#             ]
#           }
#         ],
#         "symbols": []
#       },
#       "favorited": false,
#       "retweeted": false,
#       "filter_level": "low",
#       "lang": "en",
#       "matching_rules": [
#         {
#           "tag": null
#         }
#       ]
#     }
#   ],
#   "next": "eyJtYXhJZCI6MTIyMzM5NTIyNzY3MjY5ODg4MH0=",
#   "requestParameters": {
#     "maxResults": 100,
#     "fromDate": "202001300000",
#     "toDate": "202001312359"
#   }
# }

# %% [markdown]
# When I first began this project, the first tweet was in Spanish though I meant to only include those in English, not to suppress non-American or non-English speaking voices, but because this project was not meant to be mutli-lingual. There are multilingual word embeddings by Facebook and Google that I could use once my initial exploration in English is complete. It would be facinating to look into different cultural responses to the pandemic.
#
# The first tweet also includes an image that is instrumental to the understanding of the tweet. Taking a harder look, it seems as if this particular user draws comparison between the fictional Umbrella Corporation logo from the Resident Evil videogames and a defunct Shanghai biotech firm logo (Read an article about it <a href="https://www.snopes.com/fact-check/resident-evil-umbrella-coronavirus/">here</a>.) While conspiratorial and silly, it does bring up a limitation of this project: there will be no sentiment analysis of images or videos, only text. I'll need to identify and eliminate any tweet that has a video or image significant to the context of the tweet.

# %%
# Creating pandas dataframe from result
covid_tweets = pd.DataFrame.from_dict(response['results'])

# %% [markdown]
# # Pagination
#
# Rate limits for the free Sandbox dev include 100 tweets per request and 30 requests per minute. The response includes a "next token" that can be supplied to subsequent queries in order to paginate through the results until there are no longer tweets that fit your query.
#
# I've created a helper function to pull the unique next token per request and paginate through the results. Each JSON string will then be added to the dataframe defined by the initial API request. This function can be generalized by substituting the data and template variables with a properly formatted JSON query.

# %%
# 100 tweets per request
len(covid_tweets)
# Out:
# 100

# %%
def get_initial_next_token(endpoint, headers, query=data):
    
    '''
    Takes arguments for endpoint, authorization headers, and tweet query. 
    "next" token from end of response page.
    '''
    
    response = requests.post(endpoint,data=data,headers=headers).json()
    
    if response['next']:
        return response['next']
    else:
        return 'Error'

# %%
def paginate_covid_tweets(endpoint, headers, next_token):
    
    """
    This helper function when combined with a loop will pull the next_token 
    from each request and paginate through Twitter API requests. 
    
    Keyword arguments:
    
    endpoint -- URL string of Twitter API endpoint including dev environment name
    headers -- Dictonary of OAuth bearer token and content type
    next_token -- Next_token from previous 
    request from which to begin pagination
    """ 
    
    t=Template('{"query":"(coronavirus OR Wuhan virus OR 2019-nCoV OR China flu) lang:en", "fromDate": "202001300000", "toDate": "202001312359", "next":"${next_token}"}, {"place":{"profile_country":"United States of America"}}')
    data = t.substitute(next_token=next_token)
    response = requests.post(endpoint, data=data, headers=headers).json()
    
        
    if response['next']:
               
        next_token = response['next']
        return response, next_token
    
    else:
        return response, "End of Pagination"

# %% [markdown]
# Now that we have the helper function, we'll identify the next token from the initial request, then loop through each request with the pagination function, assigning a new token to each request, and add each page to a list until we've hit the monthly rate limit of 50 requests.

# %%
# Assigning next token to variable
next_token = get_initial_next_token(endpoint, headers, query=data)

# Starting iteration at 0
i = 0
dfs = []

# Loop until rate limit of 50 is met
while i < 51:
    try:
        response, next_token = paginate_covid_tweets(endpoint, 
                                                     headers, 
                                                     next_token)
        dfs.append(response)
        i += 1
    except ValueError:
        time.sleep(60)
        continue
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-320a80ff8171> in <module>
#      11         response, next_token = paginate_covid_tweets(endpoint,
#      12                                                      headers,
# ---> 13                                                      next_token)
#      14         dfs.append(response)
#      15         i += 1
#
# <ipython-input-14-bc66a3dfbac1> in paginate_covid_tweets(endpoint, headers, next_token)
#      18
#      19
# ---> 20     if response['next']:
#      21
#      22         next_token = response['next']
#
# KeyError: 'next'

# %% [markdown]
# Below, we'll take just the tweet results, convert to dataframes, and add them to our initial covid_tweets dataframe.

# %%
for dictionary in dfs:
    df = pd.DataFrame.from_dict(dictionary['results'])
    covid_tweets = pd.concat([covid_tweets,df], axis=0)
# Out:
# /Users/Allie/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
len(covid_tweets)
# Out:
# 9300

# %%
# Final token
latest_token = dfs[-1]['next']

# %%
latest_token
# Out:
# 'eyJtYXhJZCI6MTIyMzM5MjczMTAxNzMxMDIwOX0='

# %%
# Getting the rest of the tweets after the error above
next_token = latest_token
while i < 21:
    response, next_token = paginate_covid_tweets(endpoint, 
                                                 headers, 
                                                 next_token)
    dfs.append(response)
    i += 1

# %%
#Saving last token to resume scraping next month

# with open("next_text.pickle", 'w+b') as f:
#     pickle.dump(latest_token, f)

# %%
with open("next_text.pickle", 'rb') as f:
    token = pickle.load(f)

# %% [markdown]
# After my trial and error, I've ended up with 9,300 tweets. This will become more robust, again, once the limit is reset.

# %%
len(covid_tweets)
# Out:
# 9300

# %%
covid_tweets.head()
# Out:
#   contributors coordinates                      created_at display_text_range  \
# 0         None        None  Fri Jan 31 23:58:59 +0000 2020                NaN
# 1         None        None  Fri Jan 31 23:58:59 +0000 2020                NaN
# 2         None        None  Fri Jan 31 23:58:59 +0000 2020                NaN
# 3         None        None  Fri Jan 31 23:58:59 +0000 2020                NaN
# 4         None        None  Fri Jan 31 23:58:59 +0000 2020                NaN
#
#                                             entities extended_entities  \
# 0  {'hashtags': [], 'urls': [{'url': 'https://t.c...               NaN
# 1  {'hashtags': [], 'urls': [], 'user_mentions': ...               NaN
# 2  {'hashtags': [], 'urls': [], 'user_mentions': ...               NaN
# 3  {'hashtags': [], 'urls': [], 'user_mentions': ...               NaN
# 4  {'hashtags': [], 'urls': [], 'user_mentions': ...               NaN
#
#   extended_tweet  favorite_count  favorited filter_level  ...  \
# 0            NaN               0      False          low  ...
# 1            NaN               0      False          low  ...
# 2            NaN               0      False          low  ...
# 3            NaN               0      False          low  ...
# 4            NaN               0      False          low  ...
#
#   quoted_status_id_str  quoted_status_permalink reply_count retweet_count  \
# 0                  NaN                      NaN           0             0
# 1                  NaN                      NaN           0             0
# 2                  NaN                      NaN           0             0
# 3                  NaN                      NaN           0             0
# 4                  NaN                      NaN           0             0
#
#   retweeted                                   retweeted_status  \
# 0     False  {'created_at': 'Fri Jan 31 23:30:08 +0000 2020...
# 1     False  {'created_at': 'Fri Jan 31 22:19:00 +0000 2020...
# 2     False  {'created_at': 'Fri Jan 31 21:08:39 +0000 2020...
# 3     False  {'created_at': 'Fri Jan 31 05:06:49 +0000 2020...
# 4     False  {'created_at': 'Fri Jan 31 01:27:50 +0000 2020...
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  truncated  \
# 0  RT @CNN: There have been more than 9,800 cases...      False
# 1  RT @JaneLytv: 43. Zero Hedge, a pro-Trump webs...      False
# 2  RT @skarlamangla: This flu season has killed 1...      False
# 3  RT @jamesmassola: Medical experts raise concer...      False
# 4  RT @popplioikawa: the flu: *results in 500,000...      False
#
#                                                 user
# 0  {'id': 292918761, 'id_str': '292918761', 'name...
# 1  {'id': 262334207, 'id_str': '262334207', 'name...
# 2  {'id': 2451840349, 'id_str': '2451840349', 'na...
# 3  {'id': 513208128, 'id_str': '513208128', 'name...
# 4  {'id': 993138436667314176, 'id_str': '99313843...
#
# [5 rows x 36 columns]

# %%
covid_tweets.to_csv('expanded_query_tweets_091320.csv',index=False)

# %% [markdown]
# # Next Steps

# %% [markdown]
# 1. There was an issue with the next token on my first run through with the pagination function, but as my requests for this month have reached their limit, I won't be able to investigate until next month. The function did run again when the next token was initiated with the final token of the first run.
# <br><br>
# 2. There needs to be a bit of cleanup with loops and functions.
# <br><br>
# 3. Pagination needs to exhaust all tweets pertaining to this project.
